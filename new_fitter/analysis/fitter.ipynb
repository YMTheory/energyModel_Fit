# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Etrue = [0.662, 0.834, 1.461, 2.223, 2.614, 4.945, 6.13, 7.637]
nonl1 = [0.933135, 0.946493, 0.978905, 1, 1.00645, 1.02664, 1.03172, 1.0356]
nonl2 = [0.915991, 0.929244, 0.965276, 0.987892, 0.989439, 0.998215, 0.997763, 0.993196]

plt.plot(Etrue, nonl1, "o-", label="data")
plt.plot(Etrue, nonl2, "o-", label="calc")
plt.legend()
plt.xlabel("Etrue/MeV")
plt.ylabel("nonlinearity")
plt.grid(True)
plt.savefig("twolayer_gamNL.pdf")
plt.show()
